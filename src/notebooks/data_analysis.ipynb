# %%
from src.spark.load_data import load_dataset
from src.spark.session import create_spark_session

# %%
spark = create_spark_session('test')
business_df = load_dataset(spark, "business")

# %%
business_df.printSchema()
